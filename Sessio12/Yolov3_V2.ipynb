# %% [markdown]
# <a href="https://colab.research.google.com/github/Sushmitha-Katti/Yolo-v3/blob/master/Sessio12/Yolov3_V2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
# %reload_ext autoreload
# %autoreload 2
# Out:
# Mounted at /content/gdrive

# %%
# !git clone https://github.com/Sushmitha-Katti/Yolo-v3
# Out:
# Cloning into 'Yolo-v3'...
# remote: Enumerating objects: 1302, done.
# remote: Counting objects: 100% (1302/1302), done.
# remote: Compressing objects: 100% (1266/1266), done.
# remote: Total 1302 (delta 32), reused 1290 (delta 22), pack-reused 0
# Receiving objects: 100% (1302/1302), 32.03 MiB | 21.69 MiB/s, done.
# Resolving deltas: 100% (32/32), done.

# %%
# %cd "/content/Yolo-v3"
# Out:
# /content/Yolo-v3

# %%
# !ls
# Out:
#  annotation_tool   output	  results.txt	     train.py
#  cfg		   __pycache__	  test_batch0.png   'ubdivisions=1'
#  data		   README.md	  test.py	     utils
#  detect.py	   results.json   ting		     vim.exe.stackdump
#  models.py	   results.png	  train_batch0.png

# %% [markdown]
# !python "train.py" --data data/smalcoco/smalcoco.data --batch 10 --cache --epochs 5 --nosave

# %%
# !python train.py --data data/customdata2/custom.data --batch 10  --cache --cfg "cfg/yolov3-spp-custom.cfg" --epochs 200 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-spp-custom.cfg', data='data/customdata2/custom.data', device='', epochs=200, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-04-24 13:51:01.145896: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25841e+07 parameters, 6.25841e+07 gradients
# Caching labels (47 found, 0 missing, 0 empty, 0 duplicate, for 47 images): 100% 47/47 [00:00<00:00, 9292.12it/s]
# Caching images (0.0GB): 100% 47/47 [00:00<00:00, 789.40it/s]
# ...

# %%
from utils import utils
utils.plot_results()

# %%
# !python3 detect.py --weights weights/last.pt  --cfg "cfg/yolov3-spp-custom.cfg" --names data/customdata2/custom.names --source "data/customdata/y2mate.com - You've Got A Friend In Me - Randy Newman (Toy Story Edition)_nMN4JZ8crVY_360p.mp4"
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-spp-custom.cfg', classes=None, conf_thres=0.3, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata2/custom.names', output='output', save_txt=False, source="data/customdata/y2mate.com - You've Got A Friend In Me - Randy Newman (Toy Story Edition)_nMN4JZ8crVY_360p.mp4", view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Model Summary: 225 layers, 6.25841e+07 parameters, 6.25841e+07 gradients
# video 1/1 (1/3460) data/customdata/y2mate.com - You've Got A Friend In Me - Randy Newman (Toy Story Edition)_nMN4JZ8crVY_360p.mp4: 320x512 Done. (0.017s)
# video 1/1 (2/3460) data/customdata/y2mate.com - You've Got A Friend In Me - Randy Newman (Toy Story Edition)_nMN4JZ8crVY_360p.mp4: 320x512 Done. (0.016s)
# ...
